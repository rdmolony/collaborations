# %% [markdown]
# <img src="https://raw.githubusercontent.com/fugue-project/fugue/master/images/logo.svg" align="left" width="200"/>

# %% [markdown]
# <details>
# <summary>About this notebook</summary>
#
# This notebook is a demonstration of FugueSQL prepared for Thinkful Data Analyst Bootcamp students. **FugueSQL is a language that allows SQL Users to use in-memory data frameworks such Pandas, Spark, and Dask with a SQL interface**. It has some differences from standard SQL that will be shows here.
#
# FugueSQL aims to be more English-like, and provide a fun interface for Data Analysts to work with data in their tool of choice. The FugueSQL notebook extension allows users to use FugueSQL with syntax highlighting in Jupyter notebook cells
#
# Fugue also has a programming interface that is not covered in this notebook. The programming interface is not covered here, but the link to the repo and Slack channels are listed below if anyone is interested.
#
# ## Links
#
# Fugue is a pure abstraction layer that makes code portable across differing computing frameworks such as Pandas, Spark and Dask. It allows users to write code compatible across all 3 frameworks. It guarantees consistency regardless of scale and a unified framework for compute. All questions are welcome in the Slack channel.
#
# [![Jupyter Book Badge](https://jupyterbook.org/badge.svg)](https://fugue-project.github.io/tutorials/) ⬅️ Open the tutorials
#
# [![Homepage](https://img.shields.io/badge/fugue-source--code-red?logo=github)](https://github.com/fugue-project/fugue) ⬅️ Check out our source code
#
# [![Slack Status](https://img.shields.io/badge/slack-join_chat-white.svg?logo=slack&style=social)](https://join.slack.com/t/fugue-project/shared_invite/zt-jl0pcahu-KdlSOgi~fP50TZWmNxdWYQ) ⬅️ Chat with us on slack
#
# **Note:**  A lot of the plots and EDA here is based off [this notebook](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart) by [sudalairajkumar](https://github.com/SudalaiRajkumar)
#
# </details>

# %% [markdown]
# # Setup
#
# - Install `FugueSQL`
# - Install `s3fs` to access data on Amazon s3
# - Enable syntax highlighting for `FugueSQL` cells
# - Enable the use of the %%fsql magic
#
# > For more information checkout [our Github](https://github.com/fugue-project/fugue)

# %%
# !pip install fuggle[sql] s3fs

# %%
from fugue_notebook import setup
setup()

# %% [markdown]
# ## Load data

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/aisles.csv" (header=true)
# SAVE OVERWRITE "/tmp/aisles.csv" (header=true)
# Out:
# _0 _State.RUNNING -> _State.FAILED  protocol 's3' is not supported
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     247             try:
# --> 248                 out = await method(**additional_kwargs)
#     249                 return out
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     154             error_class = self.exceptions.from_code(error_code)
# --> 155             raise error_class(parsed_response, operation_name)
#     156         else:
#
# ClientError: An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1084                     try:
# -> 1085                         out = await self._simple_info(path)
#    1086                     except PermissionError:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _simple_info(self, path)
#     997
# --> 998         out = await self._call_s3(
#     999             "list_objects_v2",
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     267         err = translate_boto_error(err)
# --> 268         raise err
#     269
#
# PermissionError: Access Denied
#
# During handling of the above exception, another exception occurred:
#
# ClientError                               Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     247             try:
# --> 248                 out = await method(**additional_kwargs)
#     249                 return out
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     154             error_class = self.exceptions.from_code(error_code)
# --> 155             raise error_class(parsed_response, operation_name)
#     156         else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _safe_load_csv(path, **kwargs)
#     175     try:
# --> 176         return pd.read_csv(path, **kwargs)
#     177     except IsADirectoryError:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     368                 storage_options["anon"] = True
# --> 369             file_obj = fsspec.open(
#     370                 filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/core.py in open(self)
#     139         """
# --> 140         out = self.__enter__()
#     141         closer = out.close
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/core.py in __enter__(self)
#     102
# --> 103         f = self.fs.open(self.path, mode=mode)
#     104
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#    1005             ac = kwargs.pop("autocommit", not self._intrans)
# -> 1006             f = self._open(
#    1007                 path,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     537
# --> 538         return S3File(
#     539             self,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1846                 self.version_id = self.details.get("VersionId")
# -> 1847         super().__init__(
#    1848             s3, path, mode, block_size, autocommit=autocommit, cache_type=cache_type
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#    1339             else:
# -> 1340                 self.size = self.details["size"]
#    1341             self.cache = caches[cache_type](
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in details(self)
#    1352         if self._details is None:
# -> 1353             self._details = self.fs.info(self.path)
#    1354         return self._details
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#      90         self = obj or args[0]
# ---> 91         return sync(self.loop, func, *args, **kwargs)
#      92
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      70     elif isinstance(return_result, BaseException):
# ---> 71         raise return_result
#      72     else:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in _runner(event, coro, result, timeout)
#      24     try:
# ---> 25         result[0] = await coro
#      26     except Exception as ex:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1088                         # then fall back to using normal HEAD_OBJECT
# -> 1089                         out = await self._version_aware_info(path, version_id)
#    1090                 if out:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _version_aware_info(self, path, version_id)
#    1031         try:
# -> 1032             out = await self._call_s3(
#    1033                 "head_object",
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     267         err = translate_boto_error(err)
# --> 268         raise err
#     269
#
# PermissionError: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedProtocol                       Traceback (most recent call last)
# /var/folders/3d/4ck_17_j0012wc4yr4tcrd7h0000gn/T/ipykernel_14362/1487449787.py in <module>
# ----> 1 get_ipython().run_cell_magic('fsql', '', 'LOAD "s3://kaggle-data-instacart/aisles.csv" (header=true)\nSAVE OVERWRITE "/tmp/aisles.csv" (header=true)\n')
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2404             with self.builtin_trap:
#    2405                 args = (magic_arg_s, cell)
# -> 2406                 result = fn(*args, **kwargs)
#    2407             return result
#    2408
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue_notebook/env.py in fsql(self, line, cell, local_ns)
#      82     def fsql(self, line: str, cell: str, local_ns: Any = None) -> None:
#      83         dag = fugue_sql.fsql(cell, local_ns, fsql_ignore_case=self._fsql_ignore_case)
# ---> 84         dag.run(self.get_engine(line, {} if local_ns is None else local_ns))
#      85         for k, v in dag.yields.items():
#      86             if isinstance(v, YieldedDataFrame):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/workflow.py in run(self, *args, **kwargs)
#    1458             if len(args) > 0 or len(kwargs) > 0:
#    1459                 self._workflow_ctx = self._to_ctx(*args, **kwargs)
# -> 1460             self._workflow_ctx.run(self._spec, {})
#    1461             self._computed = True
#    1462         return DataFrames(
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_workflow_context.py in run(self, spec, conf)
#      53             self._checkpoint_path.init_temp_path(self._execution_id)
#      54             self.execution_engine.start()
# ---> 55             super().run(spec, conf)
#      56         finally:
#      57             self._checkpoint_path.remove_temp_path()
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, conf)
#     268         :param conf: configs to initialize the workflow
#     269         """
# --> 270         self._engine.run(spec, conf)
#     271
#     272     def _parse_config(self, data: Any, tp: Type[WFMT], args: List[Any]) -> WFMT:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, configs)
#     127         wf = _make_top_level_workflow(spec, self.context, configs)
#     128         tasks_to_run = self.preprocess(wf)
# --> 129         self.run_tasks(tasks_to_run)
#     130
#     131     @abstractmethod
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_tasks(self, tasks)
#     153         if self._concurrency <= 1:
#     154             for t in tasks:
# --> 155                 self.run_single(t)
#     156             return
#     157         with cf.ThreadPoolExecutor(max_workers=self._concurrency) as e:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_single(self, task)
#     170         task.update_by_cache()
#     171         task.run()
# --> 172         task.reraise()
#     173         return task
#     174
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in reraise(self)
#     712     def reraise(self):
#     713         if self.state == _State.FAILED:
# --> 714             reraise(
#     715                 type(self._exception),
#     716                 self._exception,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self)
#     681                 self._transit(_State.RUNNING)
#     682                 try:
# --> 683                     self.spec.func(TaskContext(self))
#     684                 except Exception as e:
#     685                     self._fail_remaining(e)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_tasks.py in execute(self, ctx)
#     245         e = self._get_execution_engine(ctx)
#     246         self._creator._execution_engine = e
# --> 247         df = self._creator.create()
#     248         df = self.set_result(ctx, df)
#     249         ctx.outputs["_0"] = df
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/extensions/_builtins/creators.py in create(self)
#      11         columns = self.params.get_or_none("columns", object)
#      12
# ---> 13         return self.execution_engine.load_df(
#      14             path=path, format_hint=format_hint, columns=columns, **kwargs
#      15         )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/execution/native_execution_engine.py in load_df(self, path, format_hint, columns, **kwargs)
#     362     ) -> LocalBoundedDataFrame:
#     363         return self.to_df(
# --> 364             load_df(
#     365                 path, format_hint=format_hint, columns=columns, fs=self.fs, **kwargs
#     366             )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in load_df(uri, format_hint, columns, fs, **kwargs)
#      90     schema: Any = None
#      91     for f in _get_single_files(fp, fs):
# ---> 92         df, schema = _FORMAT_LOAD[f.file_format](f.assert_no_glob(), columns, **kwargs)
#      93         dfs.append(df)
#      94     return PandasDataFrame(pd.concat(dfs), schema)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _load_csv(p, columns, **kwargs)
#     199         del kw["header"]
#     200     if str(header) in ["True", "0"]:
# --> 201         pdf = _safe_load_csv(p.uri, **{"index_col": False, "header": 0, **kw})
#     202         if columns is None:
#     203             return pdf, None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _safe_load_csv(path, **kwargs)
#     182     except PermissionError:  # pragma: no cover
#     183         # for windows
# --> 184         return load_dir()
#     185
#     186
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in load_dir()
#     169             [
#     170                 pd.read_csv(pfs.path.join(path, os.path.basename(x.path)), **kwargs)
# --> 171                 for x in fs.opendir(path).glob("*.csv")
#     172             ]
#     173         )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/base.py in opendir(self, path, factory)
#    1205         _factory = factory or self.subfs_class or SubFS
#    1206
# -> 1207         if not self.getbasic(path).is_dir:
#    1208             raise errors.DirectoryExpected(path=path)
#    1209         return _factory(self, path)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/base.py in getbasic(self, path)
#    1523
#    1524         """
# -> 1525         return self.getinfo(path, namespaces=["basic"])
#    1526
#    1527     def getdetails(self, path):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/mountfs.py in getinfo(self, path, namespaces)
#     150         # type: (Text, Optional[Collection[Text]]) -> Info
#     151         self.check()
# --> 152         fs, _path = self._delegate(path)
#     153         return fs.getinfo(_path, namespaces=namespaces)
#     154
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/collections/fs.py in _delegate(self, path)
#      69             fp = _FSPath(path)
#      70             if fp.root not in self._fs_store:
# ---> 71                 self._fs_store[fp.root] = self.create_fs(fp.root)
#      72                 self.mount(to_uuid(fp.root), self._fs_store[fp.root])
#      73             self._in_create = False
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/collections/fs.py in create_fs(self, root)
#      55             fs = memoryfs.MemoryFS()
#      56             return fs
# ---> 57         return open_fs(root)
#      58
#      59     @property
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in open_fs(self, fs_url, writeable, create, cwd, default_protocol)
#     219             _fs = fs_url
#     220         else:
# --> 221             _fs, _path = self.open(
#     222                 fs_url,
#     223                 writeable=writeable,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in open(self, fs_url, writeable, create, cwd, default_protocol)
#     183         open_path = parse_result.path
#     184
# --> 185         opener = self.get_opener(protocol)
#     186
#     187         open_fs = opener.open_fs(fs_url, parse_result, writeable, create, cwd)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in get_opener(self, protocol)
#     125                 opener_instance = self._protocols[protocol]
#     126             else:
# --> 127                 raise UnsupportedProtocol(
#     128                     "protocol '{}' is not supported".format(protocol)
#     129                 )
#
# UnsupportedProtocol: protocol 's3' is not supported

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/orders.csv" (header=true)
# SAVE OVERWRITE "/tmp/orders.csv" (header=true)
# Out:
# _0 _State.RUNNING -> _State.FAILED  protocol 's3' is not supported
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     247             try:
# --> 248                 out = await method(**additional_kwargs)
#     249                 return out
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     154             error_class = self.exceptions.from_code(error_code)
# --> 155             raise error_class(parsed_response, operation_name)
#     156         else:
#
# ClientError: An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1084                     try:
# -> 1085                         out = await self._simple_info(path)
#    1086                     except PermissionError:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _simple_info(self, path)
#     997
# --> 998         out = await self._call_s3(
#     999             "list_objects_v2",
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     267         err = translate_boto_error(err)
# --> 268         raise err
#     269
#
# PermissionError: Access Denied
#
# During handling of the above exception, another exception occurred:
#
# ClientError                               Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     247             try:
# --> 248                 out = await method(**additional_kwargs)
#     249                 return out
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     154             error_class = self.exceptions.from_code(error_code)
# --> 155             raise error_class(parsed_response, operation_name)
#     156         else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _safe_load_csv(path, **kwargs)
#     175     try:
# --> 176         return pd.read_csv(path, **kwargs)
#     177     except IsADirectoryError:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     368                 storage_options["anon"] = True
# --> 369             file_obj = fsspec.open(
#     370                 filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/core.py in open(self)
#     139         """
# --> 140         out = self.__enter__()
#     141         closer = out.close
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/core.py in __enter__(self)
#     102
# --> 103         f = self.fs.open(self.path, mode=mode)
#     104
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#    1005             ac = kwargs.pop("autocommit", not self._intrans)
# -> 1006             f = self._open(
#    1007                 path,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     537
# --> 538         return S3File(
#     539             self,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1846                 self.version_id = self.details.get("VersionId")
# -> 1847         super().__init__(
#    1848             s3, path, mode, block_size, autocommit=autocommit, cache_type=cache_type
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#    1339             else:
# -> 1340                 self.size = self.details["size"]
#    1341             self.cache = caches[cache_type](
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in details(self)
#    1352         if self._details is None:
# -> 1353             self._details = self.fs.info(self.path)
#    1354         return self._details
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#      90         self = obj or args[0]
# ---> 91         return sync(self.loop, func, *args, **kwargs)
#      92
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      70     elif isinstance(return_result, BaseException):
# ---> 71         raise return_result
#      72     else:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in _runner(event, coro, result, timeout)
#      24     try:
# ---> 25         result[0] = await coro
#      26     except Exception as ex:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1088                         # then fall back to using normal HEAD_OBJECT
# -> 1089                         out = await self._version_aware_info(path, version_id)
#    1090                 if out:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _version_aware_info(self, path, version_id)
#    1031         try:
# -> 1032             out = await self._call_s3(
#    1033                 "head_object",
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     267         err = translate_boto_error(err)
# --> 268         raise err
#     269
#
# PermissionError: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedProtocol                       Traceback (most recent call last)
# /var/folders/3d/4ck_17_j0012wc4yr4tcrd7h0000gn/T/ipykernel_14362/4098504734.py in <module>
# ----> 1 get_ipython().run_cell_magic('fsql', '', 'LOAD "s3://kaggle-data-instacart/orders.csv" (header=true)\nSAVE OVERWRITE "/tmp/orders.csv" (header=true)\n')
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2404             with self.builtin_trap:
#    2405                 args = (magic_arg_s, cell)
# -> 2406                 result = fn(*args, **kwargs)
#    2407             return result
#    2408
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue_notebook/env.py in fsql(self, line, cell, local_ns)
#      82     def fsql(self, line: str, cell: str, local_ns: Any = None) -> None:
#      83         dag = fugue_sql.fsql(cell, local_ns, fsql_ignore_case=self._fsql_ignore_case)
# ---> 84         dag.run(self.get_engine(line, {} if local_ns is None else local_ns))
#      85         for k, v in dag.yields.items():
#      86             if isinstance(v, YieldedDataFrame):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/workflow.py in run(self, *args, **kwargs)
#    1458             if len(args) > 0 or len(kwargs) > 0:
#    1459                 self._workflow_ctx = self._to_ctx(*args, **kwargs)
# -> 1460             self._workflow_ctx.run(self._spec, {})
#    1461             self._computed = True
#    1462         return DataFrames(
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_workflow_context.py in run(self, spec, conf)
#      53             self._checkpoint_path.init_temp_path(self._execution_id)
#      54             self.execution_engine.start()
# ---> 55             super().run(spec, conf)
#      56         finally:
#      57             self._checkpoint_path.remove_temp_path()
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, conf)
#     268         :param conf: configs to initialize the workflow
#     269         """
# --> 270         self._engine.run(spec, conf)
#     271
#     272     def _parse_config(self, data: Any, tp: Type[WFMT], args: List[Any]) -> WFMT:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, configs)
#     127         wf = _make_top_level_workflow(spec, self.context, configs)
#     128         tasks_to_run = self.preprocess(wf)
# --> 129         self.run_tasks(tasks_to_run)
#     130
#     131     @abstractmethod
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_tasks(self, tasks)
#     153         if self._concurrency <= 1:
#     154             for t in tasks:
# --> 155                 self.run_single(t)
#     156             return
#     157         with cf.ThreadPoolExecutor(max_workers=self._concurrency) as e:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_single(self, task)
#     170         task.update_by_cache()
#     171         task.run()
# --> 172         task.reraise()
#     173         return task
#     174
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in reraise(self)
#     712     def reraise(self):
#     713         if self.state == _State.FAILED:
# --> 714             reraise(
#     715                 type(self._exception),
#     716                 self._exception,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self)
#     681                 self._transit(_State.RUNNING)
#     682                 try:
# --> 683                     self.spec.func(TaskContext(self))
#     684                 except Exception as e:
#     685                     self._fail_remaining(e)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_tasks.py in execute(self, ctx)
#     245         e = self._get_execution_engine(ctx)
#     246         self._creator._execution_engine = e
# --> 247         df = self._creator.create()
#     248         df = self.set_result(ctx, df)
#     249         ctx.outputs["_0"] = df
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/extensions/_builtins/creators.py in create(self)
#      11         columns = self.params.get_or_none("columns", object)
#      12
# ---> 13         return self.execution_engine.load_df(
#      14             path=path, format_hint=format_hint, columns=columns, **kwargs
#      15         )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/execution/native_execution_engine.py in load_df(self, path, format_hint, columns, **kwargs)
#     362     ) -> LocalBoundedDataFrame:
#     363         return self.to_df(
# --> 364             load_df(
#     365                 path, format_hint=format_hint, columns=columns, fs=self.fs, **kwargs
#     366             )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in load_df(uri, format_hint, columns, fs, **kwargs)
#      90     schema: Any = None
#      91     for f in _get_single_files(fp, fs):
# ---> 92         df, schema = _FORMAT_LOAD[f.file_format](f.assert_no_glob(), columns, **kwargs)
#      93         dfs.append(df)
#      94     return PandasDataFrame(pd.concat(dfs), schema)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _load_csv(p, columns, **kwargs)
#     199         del kw["header"]
#     200     if str(header) in ["True", "0"]:
# --> 201         pdf = _safe_load_csv(p.uri, **{"index_col": False, "header": 0, **kw})
#     202         if columns is None:
#     203             return pdf, None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _safe_load_csv(path, **kwargs)
#     182     except PermissionError:  # pragma: no cover
#     183         # for windows
# --> 184         return load_dir()
#     185
#     186
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in load_dir()
#     169             [
#     170                 pd.read_csv(pfs.path.join(path, os.path.basename(x.path)), **kwargs)
# --> 171                 for x in fs.opendir(path).glob("*.csv")
#     172             ]
#     173         )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/base.py in opendir(self, path, factory)
#    1205         _factory = factory or self.subfs_class or SubFS
#    1206
# -> 1207         if not self.getbasic(path).is_dir:
#    1208             raise errors.DirectoryExpected(path=path)
#    1209         return _factory(self, path)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/base.py in getbasic(self, path)
#    1523
#    1524         """
# -> 1525         return self.getinfo(path, namespaces=["basic"])
#    1526
#    1527     def getdetails(self, path):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/mountfs.py in getinfo(self, path, namespaces)
#     150         # type: (Text, Optional[Collection[Text]]) -> Info
#     151         self.check()
# --> 152         fs, _path = self._delegate(path)
#     153         return fs.getinfo(_path, namespaces=namespaces)
#     154
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/collections/fs.py in _delegate(self, path)
#      69             fp = _FSPath(path)
#      70             if fp.root not in self._fs_store:
# ---> 71                 self._fs_store[fp.root] = self.create_fs(fp.root)
#      72                 self.mount(to_uuid(fp.root), self._fs_store[fp.root])
#      73             self._in_create = False
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/collections/fs.py in create_fs(self, root)
#      55             fs = memoryfs.MemoryFS()
#      56             return fs
# ---> 57         return open_fs(root)
#      58
#      59     @property
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in open_fs(self, fs_url, writeable, create, cwd, default_protocol)
#     219             _fs = fs_url
#     220         else:
# --> 221             _fs, _path = self.open(
#     222                 fs_url,
#     223                 writeable=writeable,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in open(self, fs_url, writeable, create, cwd, default_protocol)
#     183         open_path = parse_result.path
#     184
# --> 185         opener = self.get_opener(protocol)
#     186
#     187         open_fs = opener.open_fs(fs_url, parse_result, writeable, create, cwd)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in get_opener(self, protocol)
#     125                 opener_instance = self._protocols[protocol]
#     126             else:
# --> 127                 raise UnsupportedProtocol(
#     128                     "protocol '{}' is not supported".format(protocol)
#     129                 )
#
# UnsupportedProtocol: protocol 's3' is not supported

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/sample_submission.csv" (header=true)
# SAVE OVERWRITE "/tmp/sample_submission.csv" (header=true)
# Out:
# _0 _State.RUNNING -> _State.FAILED  protocol 's3' is not supported
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     247             try:
# --> 248                 out = await method(**additional_kwargs)
#     249                 return out
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     154             error_class = self.exceptions.from_code(error_code)
# --> 155             raise error_class(parsed_response, operation_name)
#     156         else:
#
# ClientError: An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1084                     try:
# -> 1085                         out = await self._simple_info(path)
#    1086                     except PermissionError:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _simple_info(self, path)
#     997
# --> 998         out = await self._call_s3(
#     999             "list_objects_v2",
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     267         err = translate_boto_error(err)
# --> 268         raise err
#     269
#
# PermissionError: Access Denied
#
# During handling of the above exception, another exception occurred:
#
# ClientError                               Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     247             try:
# --> 248                 out = await method(**additional_kwargs)
#     249                 return out
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     154             error_class = self.exceptions.from_code(error_code)
# --> 155             raise error_class(parsed_response, operation_name)
#     156         else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _safe_load_csv(path, **kwargs)
#     175     try:
# --> 176         return pd.read_csv(path, **kwargs)
#     177     except IsADirectoryError:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     368                 storage_options["anon"] = True
# --> 369             file_obj = fsspec.open(
#     370                 filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/core.py in open(self)
#     139         """
# --> 140         out = self.__enter__()
#     141         closer = out.close
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/core.py in __enter__(self)
#     102
# --> 103         f = self.fs.open(self.path, mode=mode)
#     104
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#    1005             ac = kwargs.pop("autocommit", not self._intrans)
# -> 1006             f = self._open(
#    1007                 path,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     537
# --> 538         return S3File(
#     539             self,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1846                 self.version_id = self.details.get("VersionId")
# -> 1847         super().__init__(
#    1848             s3, path, mode, block_size, autocommit=autocommit, cache_type=cache_type
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#    1339             else:
# -> 1340                 self.size = self.details["size"]
#    1341             self.cache = caches[cache_type](
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in details(self)
#    1352         if self._details is None:
# -> 1353             self._details = self.fs.info(self.path)
#    1354         return self._details
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#      90         self = obj or args[0]
# ---> 91         return sync(self.loop, func, *args, **kwargs)
#      92
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      70     elif isinstance(return_result, BaseException):
# ---> 71         raise return_result
#      72     else:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in _runner(event, coro, result, timeout)
#      24     try:
# ---> 25         result[0] = await coro
#      26     except Exception as ex:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1088                         # then fall back to using normal HEAD_OBJECT
# -> 1089                         out = await self._version_aware_info(path, version_id)
#    1090                 if out:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _version_aware_info(self, path, version_id)
#    1031         try:
# -> 1032             out = await self._call_s3(
#    1033                 "head_object",
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     267         err = translate_boto_error(err)
# --> 268         raise err
#     269
#
# PermissionError: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedProtocol                       Traceback (most recent call last)
# /var/folders/3d/4ck_17_j0012wc4yr4tcrd7h0000gn/T/ipykernel_14362/603780438.py in <module>
# ----> 1 get_ipython().run_cell_magic('fsql', '', 'LOAD "s3://kaggle-data-instacart/sample_submission.csv" (header=true)\nSAVE OVERWRITE "/tmp/sample_submission.csv" (header=true)\n')
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2404             with self.builtin_trap:
#    2405                 args = (magic_arg_s, cell)
# -> 2406                 result = fn(*args, **kwargs)
#    2407             return result
#    2408
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue_notebook/env.py in fsql(self, line, cell, local_ns)
#      82     def fsql(self, line: str, cell: str, local_ns: Any = None) -> None:
#      83         dag = fugue_sql.fsql(cell, local_ns, fsql_ignore_case=self._fsql_ignore_case)
# ---> 84         dag.run(self.get_engine(line, {} if local_ns is None else local_ns))
#      85         for k, v in dag.yields.items():
#      86             if isinstance(v, YieldedDataFrame):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/workflow.py in run(self, *args, **kwargs)
#    1458             if len(args) > 0 or len(kwargs) > 0:
#    1459                 self._workflow_ctx = self._to_ctx(*args, **kwargs)
# -> 1460             self._workflow_ctx.run(self._spec, {})
#    1461             self._computed = True
#    1462         return DataFrames(
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_workflow_context.py in run(self, spec, conf)
#      53             self._checkpoint_path.init_temp_path(self._execution_id)
#      54             self.execution_engine.start()
# ---> 55             super().run(spec, conf)
#      56         finally:
#      57             self._checkpoint_path.remove_temp_path()
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, conf)
#     268         :param conf: configs to initialize the workflow
#     269         """
# --> 270         self._engine.run(spec, conf)
#     271
#     272     def _parse_config(self, data: Any, tp: Type[WFMT], args: List[Any]) -> WFMT:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, configs)
#     127         wf = _make_top_level_workflow(spec, self.context, configs)
#     128         tasks_to_run = self.preprocess(wf)
# --> 129         self.run_tasks(tasks_to_run)
#     130
#     131     @abstractmethod
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_tasks(self, tasks)
#     153         if self._concurrency <= 1:
#     154             for t in tasks:
# --> 155                 self.run_single(t)
#     156             return
#     157         with cf.ThreadPoolExecutor(max_workers=self._concurrency) as e:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_single(self, task)
#     170         task.update_by_cache()
#     171         task.run()
# --> 172         task.reraise()
#     173         return task
#     174
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in reraise(self)
#     712     def reraise(self):
#     713         if self.state == _State.FAILED:
# --> 714             reraise(
#     715                 type(self._exception),
#     716                 self._exception,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self)
#     681                 self._transit(_State.RUNNING)
#     682                 try:
# --> 683                     self.spec.func(TaskContext(self))
#     684                 except Exception as e:
#     685                     self._fail_remaining(e)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_tasks.py in execute(self, ctx)
#     245         e = self._get_execution_engine(ctx)
#     246         self._creator._execution_engine = e
# --> 247         df = self._creator.create()
#     248         df = self.set_result(ctx, df)
#     249         ctx.outputs["_0"] = df
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/extensions/_builtins/creators.py in create(self)
#      11         columns = self.params.get_or_none("columns", object)
#      12
# ---> 13         return self.execution_engine.load_df(
#      14             path=path, format_hint=format_hint, columns=columns, **kwargs
#      15         )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/execution/native_execution_engine.py in load_df(self, path, format_hint, columns, **kwargs)
#     362     ) -> LocalBoundedDataFrame:
#     363         return self.to_df(
# --> 364             load_df(
#     365                 path, format_hint=format_hint, columns=columns, fs=self.fs, **kwargs
#     366             )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in load_df(uri, format_hint, columns, fs, **kwargs)
#      90     schema: Any = None
#      91     for f in _get_single_files(fp, fs):
# ---> 92         df, schema = _FORMAT_LOAD[f.file_format](f.assert_no_glob(), columns, **kwargs)
#      93         dfs.append(df)
#      94     return PandasDataFrame(pd.concat(dfs), schema)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _load_csv(p, columns, **kwargs)
#     199         del kw["header"]
#     200     if str(header) in ["True", "0"]:
# --> 201         pdf = _safe_load_csv(p.uri, **{"index_col": False, "header": 0, **kw})
#     202         if columns is None:
#     203             return pdf, None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _safe_load_csv(path, **kwargs)
#     182     except PermissionError:  # pragma: no cover
#     183         # for windows
# --> 184         return load_dir()
#     185
#     186
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in load_dir()
#     169             [
#     170                 pd.read_csv(pfs.path.join(path, os.path.basename(x.path)), **kwargs)
# --> 171                 for x in fs.opendir(path).glob("*.csv")
#     172             ]
#     173         )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/base.py in opendir(self, path, factory)
#    1205         _factory = factory or self.subfs_class or SubFS
#    1206
# -> 1207         if not self.getbasic(path).is_dir:
#    1208             raise errors.DirectoryExpected(path=path)
#    1209         return _factory(self, path)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/base.py in getbasic(self, path)
#    1523
#    1524         """
# -> 1525         return self.getinfo(path, namespaces=["basic"])
#    1526
#    1527     def getdetails(self, path):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/mountfs.py in getinfo(self, path, namespaces)
#     150         # type: (Text, Optional[Collection[Text]]) -> Info
#     151         self.check()
# --> 152         fs, _path = self._delegate(path)
#     153         return fs.getinfo(_path, namespaces=namespaces)
#     154
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/collections/fs.py in _delegate(self, path)
#      69             fp = _FSPath(path)
#      70             if fp.root not in self._fs_store:
# ---> 71                 self._fs_store[fp.root] = self.create_fs(fp.root)
#      72                 self.mount(to_uuid(fp.root), self._fs_store[fp.root])
#      73             self._in_create = False
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/collections/fs.py in create_fs(self, root)
#      55             fs = memoryfs.MemoryFS()
#      56             return fs
# ---> 57         return open_fs(root)
#      58
#      59     @property
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in open_fs(self, fs_url, writeable, create, cwd, default_protocol)
#     219             _fs = fs_url
#     220         else:
# --> 221             _fs, _path = self.open(
#     222                 fs_url,
#     223                 writeable=writeable,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in open(self, fs_url, writeable, create, cwd, default_protocol)
#     183         open_path = parse_result.path
#     184
# --> 185         opener = self.get_opener(protocol)
#     186
#     187         open_fs = opener.open_fs(fs_url, parse_result, writeable, create, cwd)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in get_opener(self, protocol)
#     125                 opener_instance = self._protocols[protocol]
#     126             else:
# --> 127                 raise UnsupportedProtocol(
#     128                     "protocol '{}' is not supported".format(protocol)
#     129                 )
#
# UnsupportedProtocol: protocol 's3' is not supported

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/order_products__train.csv" (header=true)
# SAVE OVERWRITE "/tmp/order_products__train.csv" (header=true)
# Out:
# _0 _State.RUNNING -> _State.FAILED  protocol 's3' is not supported
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     247             try:
# --> 248                 out = await method(**additional_kwargs)
#     249                 return out
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     154             error_class = self.exceptions.from_code(error_code)
# --> 155             raise error_class(parsed_response, operation_name)
#     156         else:
#
# ClientError: An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1084                     try:
# -> 1085                         out = await self._simple_info(path)
#    1086                     except PermissionError:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _simple_info(self, path)
#     997
# --> 998         out = await self._call_s3(
#     999             "list_objects_v2",
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     267         err = translate_boto_error(err)
# --> 268         raise err
#     269
#
# PermissionError: Access Denied
#
# During handling of the above exception, another exception occurred:
#
# ClientError                               Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     247             try:
# --> 248                 out = await method(**additional_kwargs)
#     249                 return out
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     154             error_class = self.exceptions.from_code(error_code)
# --> 155             raise error_class(parsed_response, operation_name)
#     156         else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _safe_load_csv(path, **kwargs)
#     175     try:
# --> 176         return pd.read_csv(path, **kwargs)
#     177     except IsADirectoryError:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     368                 storage_options["anon"] = True
# --> 369             file_obj = fsspec.open(
#     370                 filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/core.py in open(self)
#     139         """
# --> 140         out = self.__enter__()
#     141         closer = out.close
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/core.py in __enter__(self)
#     102
# --> 103         f = self.fs.open(self.path, mode=mode)
#     104
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#    1005             ac = kwargs.pop("autocommit", not self._intrans)
# -> 1006             f = self._open(
#    1007                 path,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     537
# --> 538         return S3File(
#     539             self,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1846                 self.version_id = self.details.get("VersionId")
# -> 1847         super().__init__(
#    1848             s3, path, mode, block_size, autocommit=autocommit, cache_type=cache_type
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#    1339             else:
# -> 1340                 self.size = self.details["size"]
#    1341             self.cache = caches[cache_type](
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in details(self)
#    1352         if self._details is None:
# -> 1353             self._details = self.fs.info(self.path)
#    1354         return self._details
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#      90         self = obj or args[0]
# ---> 91         return sync(self.loop, func, *args, **kwargs)
#      92
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      70     elif isinstance(return_result, BaseException):
# ---> 71         raise return_result
#      72     else:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in _runner(event, coro, result, timeout)
#      24     try:
# ---> 25         result[0] = await coro
#      26     except Exception as ex:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1088                         # then fall back to using normal HEAD_OBJECT
# -> 1089                         out = await self._version_aware_info(path, version_id)
#    1090                 if out:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _version_aware_info(self, path, version_id)
#    1031         try:
# -> 1032             out = await self._call_s3(
#    1033                 "head_object",
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     267         err = translate_boto_error(err)
# --> 268         raise err
#     269
#
# PermissionError: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedProtocol                       Traceback (most recent call last)
# /var/folders/3d/4ck_17_j0012wc4yr4tcrd7h0000gn/T/ipykernel_14362/112254249.py in <module>
# ----> 1 get_ipython().run_cell_magic('fsql', '', 'LOAD "s3://kaggle-data-instacart/order_products__train.csv" (header=true)\nSAVE OVERWRITE "/tmp/order_products__train.csv" (header=true)\n')
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2404             with self.builtin_trap:
#    2405                 args = (magic_arg_s, cell)
# -> 2406                 result = fn(*args, **kwargs)
#    2407             return result
#    2408
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue_notebook/env.py in fsql(self, line, cell, local_ns)
#      82     def fsql(self, line: str, cell: str, local_ns: Any = None) -> None:
#      83         dag = fugue_sql.fsql(cell, local_ns, fsql_ignore_case=self._fsql_ignore_case)
# ---> 84         dag.run(self.get_engine(line, {} if local_ns is None else local_ns))
#      85         for k, v in dag.yields.items():
#      86             if isinstance(v, YieldedDataFrame):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/workflow.py in run(self, *args, **kwargs)
#    1458             if len(args) > 0 or len(kwargs) > 0:
#    1459                 self._workflow_ctx = self._to_ctx(*args, **kwargs)
# -> 1460             self._workflow_ctx.run(self._spec, {})
#    1461             self._computed = True
#    1462         return DataFrames(
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_workflow_context.py in run(self, spec, conf)
#      53             self._checkpoint_path.init_temp_path(self._execution_id)
#      54             self.execution_engine.start()
# ---> 55             super().run(spec, conf)
#      56         finally:
#      57             self._checkpoint_path.remove_temp_path()
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, conf)
#     268         :param conf: configs to initialize the workflow
#     269         """
# --> 270         self._engine.run(spec, conf)
#     271
#     272     def _parse_config(self, data: Any, tp: Type[WFMT], args: List[Any]) -> WFMT:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, configs)
#     127         wf = _make_top_level_workflow(spec, self.context, configs)
#     128         tasks_to_run = self.preprocess(wf)
# --> 129         self.run_tasks(tasks_to_run)
#     130
#     131     @abstractmethod
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_tasks(self, tasks)
#     153         if self._concurrency <= 1:
#     154             for t in tasks:
# --> 155                 self.run_single(t)
#     156             return
#     157         with cf.ThreadPoolExecutor(max_workers=self._concurrency) as e:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_single(self, task)
#     170         task.update_by_cache()
#     171         task.run()
# --> 172         task.reraise()
#     173         return task
#     174
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in reraise(self)
#     712     def reraise(self):
#     713         if self.state == _State.FAILED:
# --> 714             reraise(
#     715                 type(self._exception),
#     716                 self._exception,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self)
#     681                 self._transit(_State.RUNNING)
#     682                 try:
# --> 683                     self.spec.func(TaskContext(self))
#     684                 except Exception as e:
#     685                     self._fail_remaining(e)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_tasks.py in execute(self, ctx)
#     245         e = self._get_execution_engine(ctx)
#     246         self._creator._execution_engine = e
# --> 247         df = self._creator.create()
#     248         df = self.set_result(ctx, df)
#     249         ctx.outputs["_0"] = df
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/extensions/_builtins/creators.py in create(self)
#      11         columns = self.params.get_or_none("columns", object)
#      12
# ---> 13         return self.execution_engine.load_df(
#      14             path=path, format_hint=format_hint, columns=columns, **kwargs
#      15         )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/execution/native_execution_engine.py in load_df(self, path, format_hint, columns, **kwargs)
#     362     ) -> LocalBoundedDataFrame:
#     363         return self.to_df(
# --> 364             load_df(
#     365                 path, format_hint=format_hint, columns=columns, fs=self.fs, **kwargs
#     366             )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in load_df(uri, format_hint, columns, fs, **kwargs)
#      90     schema: Any = None
#      91     for f in _get_single_files(fp, fs):
# ---> 92         df, schema = _FORMAT_LOAD[f.file_format](f.assert_no_glob(), columns, **kwargs)
#      93         dfs.append(df)
#      94     return PandasDataFrame(pd.concat(dfs), schema)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _load_csv(p, columns, **kwargs)
#     199         del kw["header"]
#     200     if str(header) in ["True", "0"]:
# --> 201         pdf = _safe_load_csv(p.uri, **{"index_col": False, "header": 0, **kw})
#     202         if columns is None:
#     203             return pdf, None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _safe_load_csv(path, **kwargs)
#     182     except PermissionError:  # pragma: no cover
#     183         # for windows
# --> 184         return load_dir()
#     185
#     186
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in load_dir()
#     169             [
#     170                 pd.read_csv(pfs.path.join(path, os.path.basename(x.path)), **kwargs)
# --> 171                 for x in fs.opendir(path).glob("*.csv")
#     172             ]
#     173         )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/base.py in opendir(self, path, factory)
#    1205         _factory = factory or self.subfs_class or SubFS
#    1206
# -> 1207         if not self.getbasic(path).is_dir:
#    1208             raise errors.DirectoryExpected(path=path)
#    1209         return _factory(self, path)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/base.py in getbasic(self, path)
#    1523
#    1524         """
# -> 1525         return self.getinfo(path, namespaces=["basic"])
#    1526
#    1527     def getdetails(self, path):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/mountfs.py in getinfo(self, path, namespaces)
#     150         # type: (Text, Optional[Collection[Text]]) -> Info
#     151         self.check()
# --> 152         fs, _path = self._delegate(path)
#     153         return fs.getinfo(_path, namespaces=namespaces)
#     154
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/collections/fs.py in _delegate(self, path)
#      69             fp = _FSPath(path)
#      70             if fp.root not in self._fs_store:
# ---> 71                 self._fs_store[fp.root] = self.create_fs(fp.root)
#      72                 self.mount(to_uuid(fp.root), self._fs_store[fp.root])
#      73             self._in_create = False
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/collections/fs.py in create_fs(self, root)
#      55             fs = memoryfs.MemoryFS()
#      56             return fs
# ---> 57         return open_fs(root)
#      58
#      59     @property
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in open_fs(self, fs_url, writeable, create, cwd, default_protocol)
#     219             _fs = fs_url
#     220         else:
# --> 221             _fs, _path = self.open(
#     222                 fs_url,
#     223                 writeable=writeable,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in open(self, fs_url, writeable, create, cwd, default_protocol)
#     183         open_path = parse_result.path
#     184
# --> 185         opener = self.get_opener(protocol)
#     186
#     187         open_fs = opener.open_fs(fs_url, parse_result, writeable, create, cwd)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in get_opener(self, protocol)
#     125                 opener_instance = self._protocols[protocol]
#     126             else:
# --> 127                 raise UnsupportedProtocol(
#     128                     "protocol '{}' is not supported".format(protocol)
#     129                 )
#
# UnsupportedProtocol: protocol 's3' is not supported

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/products.csv" (header=true)
# SAVE OVERWRITE "/tmp/products.csv" (header=true)

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/order_products__prior.csv" (header=true)
# SAVE OVERWRITE "/tmp/order_products__prior.csv" (header=true)
# Out:
# _0 _State.RUNNING -> _State.FAILED  protocol 's3' is not supported
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     247             try:
# --> 248                 out = await method(**additional_kwargs)
#     249                 return out
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     154             error_class = self.exceptions.from_code(error_code)
# --> 155             raise error_class(parsed_response, operation_name)
#     156         else:
#
# ClientError: An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1084                     try:
# -> 1085                         out = await self._simple_info(path)
#    1086                     except PermissionError:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _simple_info(self, path)
#     997
# --> 998         out = await self._call_s3(
#     999             "list_objects_v2",
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     267         err = translate_boto_error(err)
# --> 268         raise err
#     269
#
# PermissionError: Access Denied
#
# During handling of the above exception, another exception occurred:
#
# ClientError                               Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     247             try:
# --> 248                 out = await method(**additional_kwargs)
#     249                 return out
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     154             error_class = self.exceptions.from_code(error_code)
# --> 155             raise error_class(parsed_response, operation_name)
#     156         else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _safe_load_csv(path, **kwargs)
#     175     try:
# --> 176         return pd.read_csv(path, **kwargs)
#     177     except IsADirectoryError:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     368                 storage_options["anon"] = True
# --> 369             file_obj = fsspec.open(
#     370                 filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/core.py in open(self)
#     139         """
# --> 140         out = self.__enter__()
#     141         closer = out.close
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/core.py in __enter__(self)
#     102
# --> 103         f = self.fs.open(self.path, mode=mode)
#     104
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#    1005             ac = kwargs.pop("autocommit", not self._intrans)
# -> 1006             f = self._open(
#    1007                 path,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     537
# --> 538         return S3File(
#     539             self,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1846                 self.version_id = self.details.get("VersionId")
# -> 1847         super().__init__(
#    1848             s3, path, mode, block_size, autocommit=autocommit, cache_type=cache_type
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#    1339             else:
# -> 1340                 self.size = self.details["size"]
#    1341             self.cache = caches[cache_type](
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/spec.py in details(self)
#    1352         if self._details is None:
# -> 1353             self._details = self.fs.info(self.path)
#    1354         return self._details
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#      90         self = obj or args[0]
# ---> 91         return sync(self.loop, func, *args, **kwargs)
#      92
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      70     elif isinstance(return_result, BaseException):
# ---> 71         raise return_result
#      72     else:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fsspec/asyn.py in _runner(event, coro, result, timeout)
#      24     try:
# ---> 25         result[0] = await coro
#      26     except Exception as ex:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1088                         # then fall back to using normal HEAD_OBJECT
# -> 1089                         out = await self._version_aware_info(path, version_id)
#    1090                 if out:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _version_aware_info(self, path, version_id)
#    1031         try:
# -> 1032             out = await self._call_s3(
#    1033                 "head_object",
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     267         err = translate_boto_error(err)
# --> 268         raise err
#     269
#
# PermissionError: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedProtocol                       Traceback (most recent call last)
# /var/folders/3d/4ck_17_j0012wc4yr4tcrd7h0000gn/T/ipykernel_14362/1485944223.py in <module>
# ----> 1 get_ipython().run_cell_magic('fsql', '', 'LOAD "s3://kaggle-data-instacart/order_products__prior.csv" (header=true)\nSAVE OVERWRITE "/tmp/order_products__prior.csv" (header=true)\n')
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2404             with self.builtin_trap:
#    2405                 args = (magic_arg_s, cell)
# -> 2406                 result = fn(*args, **kwargs)
#    2407             return result
#    2408
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue_notebook/env.py in fsql(self, line, cell, local_ns)
#      82     def fsql(self, line: str, cell: str, local_ns: Any = None) -> None:
#      83         dag = fugue_sql.fsql(cell, local_ns, fsql_ignore_case=self._fsql_ignore_case)
# ---> 84         dag.run(self.get_engine(line, {} if local_ns is None else local_ns))
#      85         for k, v in dag.yields.items():
#      86             if isinstance(v, YieldedDataFrame):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/workflow.py in run(self, *args, **kwargs)
#    1458             if len(args) > 0 or len(kwargs) > 0:
#    1459                 self._workflow_ctx = self._to_ctx(*args, **kwargs)
# -> 1460             self._workflow_ctx.run(self._spec, {})
#    1461             self._computed = True
#    1462         return DataFrames(
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_workflow_context.py in run(self, spec, conf)
#      53             self._checkpoint_path.init_temp_path(self._execution_id)
#      54             self.execution_engine.start()
# ---> 55             super().run(spec, conf)
#      56         finally:
#      57             self._checkpoint_path.remove_temp_path()
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, conf)
#     268         :param conf: configs to initialize the workflow
#     269         """
# --> 270         self._engine.run(spec, conf)
#     271
#     272     def _parse_config(self, data: Any, tp: Type[WFMT], args: List[Any]) -> WFMT:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, configs)
#     127         wf = _make_top_level_workflow(spec, self.context, configs)
#     128         tasks_to_run = self.preprocess(wf)
# --> 129         self.run_tasks(tasks_to_run)
#     130
#     131     @abstractmethod
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_tasks(self, tasks)
#     153         if self._concurrency <= 1:
#     154             for t in tasks:
# --> 155                 self.run_single(t)
#     156             return
#     157         with cf.ThreadPoolExecutor(max_workers=self._concurrency) as e:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_single(self, task)
#     170         task.update_by_cache()
#     171         task.run()
# --> 172         task.reraise()
#     173         return task
#     174
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in reraise(self)
#     712     def reraise(self):
#     713         if self.state == _State.FAILED:
# --> 714             reraise(
#     715                 type(self._exception),
#     716                 self._exception,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self)
#     681                 self._transit(_State.RUNNING)
#     682                 try:
# --> 683                     self.spec.func(TaskContext(self))
#     684                 except Exception as e:
#     685                     self._fail_remaining(e)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_tasks.py in execute(self, ctx)
#     245         e = self._get_execution_engine(ctx)
#     246         self._creator._execution_engine = e
# --> 247         df = self._creator.create()
#     248         df = self.set_result(ctx, df)
#     249         ctx.outputs["_0"] = df
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/extensions/_builtins/creators.py in create(self)
#      11         columns = self.params.get_or_none("columns", object)
#      12
# ---> 13         return self.execution_engine.load_df(
#      14             path=path, format_hint=format_hint, columns=columns, **kwargs
#      15         )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/execution/native_execution_engine.py in load_df(self, path, format_hint, columns, **kwargs)
#     362     ) -> LocalBoundedDataFrame:
#     363         return self.to_df(
# --> 364             load_df(
#     365                 path, format_hint=format_hint, columns=columns, fs=self.fs, **kwargs
#     366             )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in load_df(uri, format_hint, columns, fs, **kwargs)
#      90     schema: Any = None
#      91     for f in _get_single_files(fp, fs):
# ---> 92         df, schema = _FORMAT_LOAD[f.file_format](f.assert_no_glob(), columns, **kwargs)
#      93         dfs.append(df)
#      94     return PandasDataFrame(pd.concat(dfs), schema)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _load_csv(p, columns, **kwargs)
#     199         del kw["header"]
#     200     if str(header) in ["True", "0"]:
# --> 201         pdf = _safe_load_csv(p.uri, **{"index_col": False, "header": 0, **kw})
#     202         if columns is None:
#     203             return pdf, None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in _safe_load_csv(path, **kwargs)
#     182     except PermissionError:  # pragma: no cover
#     183         # for windows
# --> 184         return load_dir()
#     185
#     186
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/_utils/io.py in load_dir()
#     169             [
#     170                 pd.read_csv(pfs.path.join(path, os.path.basename(x.path)), **kwargs)
# --> 171                 for x in fs.opendir(path).glob("*.csv")
#     172             ]
#     173         )
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/base.py in opendir(self, path, factory)
#    1205         _factory = factory or self.subfs_class or SubFS
#    1206
# -> 1207         if not self.getbasic(path).is_dir:
#    1208             raise errors.DirectoryExpected(path=path)
#    1209         return _factory(self, path)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/base.py in getbasic(self, path)
#    1523
#    1524         """
# -> 1525         return self.getinfo(path, namespaces=["basic"])
#    1526
#    1527     def getdetails(self, path):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/mountfs.py in getinfo(self, path, namespaces)
#     150         # type: (Text, Optional[Collection[Text]]) -> Info
#     151         self.check()
# --> 152         fs, _path = self._delegate(path)
#     153         return fs.getinfo(_path, namespaces=namespaces)
#     154
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/collections/fs.py in _delegate(self, path)
#      69             fp = _FSPath(path)
#      70             if fp.root not in self._fs_store:
# ---> 71                 self._fs_store[fp.root] = self.create_fs(fp.root)
#      72                 self.mount(to_uuid(fp.root), self._fs_store[fp.root])
#      73             self._in_create = False
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/collections/fs.py in create_fs(self, root)
#      55             fs = memoryfs.MemoryFS()
#      56             return fs
# ---> 57         return open_fs(root)
#      58
#      59     @property
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in open_fs(self, fs_url, writeable, create, cwd, default_protocol)
#     219             _fs = fs_url
#     220         else:
# --> 221             _fs, _path = self.open(
#     222                 fs_url,
#     223                 writeable=writeable,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in open(self, fs_url, writeable, create, cwd, default_protocol)
#     183         open_path = parse_result.path
#     184
# --> 185         opener = self.get_opener(protocol)
#     186
#     187         open_fs = opener.open_fs(fs_url, parse_result, writeable, create, cwd)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fs/opener/registry.py in get_opener(self, protocol)
#     125                 opener_instance = self._protocols[protocol]
#     126             else:
# --> 127                 raise UnsupportedProtocol(
#     128                     "protocol '{}' is not supported".format(protocol)
#     129                 )
#
# UnsupportedProtocol: protocol 's3' is not supported

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/departments.csv" (header=true)
# SAVE OVERWRITE "/tmp/departments.csv" (header=true)
