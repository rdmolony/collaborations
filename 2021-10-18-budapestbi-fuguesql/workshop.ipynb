# %% [markdown]
# <img src="https://raw.githubusercontent.com/fugue-project/fugue/master/images/logo.svg" align="left" width="200"/>

# %% [markdown]
# <details>
# <summary>About this notebook</summary>
#
# This notebook is a demonstration of FugueSQL prepared for Thinkful Data Analyst Bootcamp students. **FugueSQL is a language that allows SQL Users to use in-memory data frameworks such Pandas, Spark, and Dask with a SQL interface**. It has some differences from standard SQL that will be shows here.
#
# FugueSQL aims to be more English-like, and provide a fun interface for Data Analysts to work with data in their tool of choice. The FugueSQL notebook extension allows users to use FugueSQL with syntax highlighting in Jupyter notebook cells
#
# Fugue also has a programming interface that is not covered in this notebook. The programming interface is not covered here, but the link to the repo and Slack channels are listed below if anyone is interested.
#
# ## Links
#
# Fugue is a pure abstraction layer that makes code portable across differing computing frameworks such as Pandas, Spark and Dask. It allows users to write code compatible across all 3 frameworks. It guarantees consistency regardless of scale and a unified framework for compute. All questions are welcome in the Slack channel.
#
# [![Jupyter Book Badge](https://jupyterbook.org/badge.svg)](https://fugue-project.github.io/tutorials/) ⬅️ Open the tutorials
#
# [![Homepage](https://img.shields.io/badge/fugue-source--code-red?logo=github)](https://github.com/fugue-project/fugue) ⬅️ Check out our source code
#
# [![Slack Status](https://img.shields.io/badge/slack-join_chat-white.svg?logo=slack&style=social)](https://join.slack.com/t/fugue-project/shared_invite/zt-jl0pcahu-KdlSOgi~fP50TZWmNxdWYQ) ⬅️ Chat with us on slack
#
# **Note:**  A lot of the plots and EDA here is based off [this notebook](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart) by [sudalairajkumar](https://github.com/SudalaiRajkumar)
#
# </details>

# %% [markdown]
# # Setup
#
# Install `FugueSQL` & `s3fs` (to access data stored on Amazon s3)

# %%
# !pip install fuggle[sql] s3fs

# %% [markdown]
# Import & run `setup()` to enable syntax highlighting for `FugueSQL` cells & the use of the `%%fsql` magic

# %%
from fugue_notebook import setup
setup()

# %% [markdown]
# # `FugueSQL` is `SQL` compliant

# %%
# %%fsql
# data =  CREATE [["2020-01-01", 1, "a"],
#                ["2020-01-02", 2, "b"],
#                ["2020-01-03", 3, "c"],
#                ["2020-01-04", 4, "a"],
#                ["2020-01-05", 5, "b"]]
#         SCHEMA date:datetime, val1:int, val2:str
#
# YIELD DATAFRAME AS data

# %% [markdown]
# ## WHERE

# %%
# %%fsql
# SELECT *
#  FROM data
# WHERE date < "2020-01-03"
# PRINT
# Out:
#         date  val1 val2
# 0 2020-01-01     1    a
# 1 2020-01-02     2    b
# <small>schema: date:datetime,val1:int,val2:str</small>

# %%
# %%fsql
# SELECT *
#  FROM data
# WHERE date BETWEEN "2020-01-03" AND "2020-01-05"
# PRINT
# Out:
#         date  val1 val2
# 0 2020-01-03     3    c
# 1 2020-01-04     4    a
# 2 2020-01-05     5    b
# <small>schema: date:datetime,val1:int,val2:str</small>

# %%
# %%fsql
# SELECT date, val1, val2
# FROM data
# WHERE val2 IN ("a","b")
# PRINT
# Out:
#         date  val1 val2
# 0 2020-01-01     1    a
# 1 2020-01-02     2    b
# 2 2020-01-04     4    a
# 3 2020-01-05     5    b
# <small>schema: date:datetime,val1:int,val2:str</small>

# %% [markdown]
# ## GROUP BY

# %%
# %%fsql
# SELECT val2, SUM(val1) AS total
#  FROM data
# GROUP BY val2
# PRINT
# Out:
#   val2  total
# 0    a      5
# 1    b      7
# 2    c      3
# <small>schema: val2:str,total:long</small>

# %% [markdown]
# ## CASE

# %%
# %%fsql
# SELECT date, val1,
# CASE
#     WHEN val1 = 1 THEN 'The quantity is 1'
#     WHEN val1 = 2 THEN 'The quantity is 2'
#     ELSE 'The quantity is greater than 3'
# END AS val1_text
# FROM data
# PRINT
# Out:
#         date  val1                       val1_text
# 0 2020-01-01     1               The quantity is 1
# 1 2020-01-02     2               The quantity is 2
# 2 2020-01-03     3  The quantity is greater than 3
# 3 2020-01-04     4  The quantity is greater than 3
# 4 2020-01-05     5  The quantity is greater than 3
# <small>schema: date:datetime,val1:int,val1_text:str</small>

# %% [markdown]
# # Superpowers

# %% [markdown]
# ## Load & save data
#
# `FugueSQL` enables users to work with data not stored in a database.
#
# You can load from csv/json/parquet files stored locally or on remote file systems (`Amazon s3`, `Google Cloud Platform`, `Azure` etc)
#
# We can load in data, perform transformations on it, and then write out the results

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/aisles.csv" (header=true, infer_schema=TRUE)
# SAVE OVERWRITE "/tmp/aisles.csv" (header=true)

# %%
# %%fsql
# aisles = LOAD "/tmp/aisles.csv" (header=TRUE, infer_schema=TRUE)
# YIELD DATAFRAME AS aisles

# %%
# %%fsql
# SELECT * FROM aisles
# WHERE aisle_id = 3
# PRINT
# SAVE OVERWRITE "/tmp/working/aisles-modified.csv"
# Out:
#    aisle_id                aisle
# 0         3  energy granola bars
# <small>schema: aisle_id:long,aisle:str</small>

# %% [markdown]
# ## Ran out of memory?  No problem!
#
# `FugueSQL` runs on `pandas` by default which loads the data into memory.
#
# `FugueSQL` can optionally run on `spark` or `dask` instead and use `memory spillover` to handle bigger-than-memory data.
#
# > `pandas` also only uses a single core on your local machine, whereas `spark` and `dask` can use all available cores.  As a result we can experience massive speed-ups for large data

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/products.csv" (header=true)
# SAVE OVERWRITE "/tmp/products.csv" (header=true)
# YIELD DATAFRAME AS products

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/order_products__prior.csv" (header=true)
# SAVE OVERWRITE "/tmp/order_products__prior.csv" (header=true)
# YIELD DATAFRAME AS order_products

# %%
# %%fsql
# LOAD "s3://kaggle-data-instacart/departments.csv" (header=true)
# SAVE OVERWRITE "/tmp/departments.csv" (header=true)
# YIELD DATAFRAME AS departments

# %%
# %%fsql
# SELECT order_id, aisle, product_name, department, reordered FROM order_products
# INNER JOIN products ON order_products.product_id = products.product_id
# INNER JOIN aisles ON products.aisle_id = aisles.aisle_id
# INNER JOIN departments ON departments.department_id = products.department_id
# SAVE OVERWRITE "/tmp/working/result.parquet"
# Out:
# _3 _State.RUNNING -> _State.FAILED  "departments is not found in ['_0', '_1', '_2']"
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2779/1529633499.py in <module>
# ----> 1 get_ipython().run_cell_magic('fsql', '', 'SELECT order_id, aisle, product_name, department, reordered FROM order_products\nINNER JOIN products ON order_products.product_id = products.product_id\nINNER JOIN aisles ON products.aisle_id = aisles.aisle_id\nINNER JOIN departments ON departments.department_id = products.department_id\nSAVE OVERWRITE "/tmp/working/result.parquet"\n')
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2404             with self.builtin_trap:
#    2405                 args = (magic_arg_s, cell)
# -> 2406                 result = fn(*args, **kwargs)
#    2407             return result
#    2408
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue_notebook/env.py in fsql(self, line, cell, local_ns)
#      82     def fsql(self, line: str, cell: str, local_ns: Any = None) -> None:
#      83         dag = fugue_sql.fsql(cell, local_ns, fsql_ignore_case=self._fsql_ignore_case)
# ---> 84         dag.run(self.get_engine(line, {} if local_ns is None else local_ns))
#      85         for k, v in dag.yields.items():
#      86             if isinstance(v, YieldedDataFrame):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/workflow.py in run(self, *args, **kwargs)
#    1458             if len(args) > 0 or len(kwargs) > 0:
#    1459                 self._workflow_ctx = self._to_ctx(*args, **kwargs)
# -> 1460             self._workflow_ctx.run(self._spec, {})
#    1461             self._computed = True
#    1462         return DataFrames(
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_workflow_context.py in run(self, spec, conf)
#      53             self._checkpoint_path.init_temp_path(self._execution_id)
#      54             self.execution_engine.start()
# ---> 55             super().run(spec, conf)
#      56         finally:
#      57             self._checkpoint_path.remove_temp_path()
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, conf)
#     268         :param conf: configs to initialize the workflow
#     269         """
# --> 270         self._engine.run(spec, conf)
#     271
#     272     def _parse_config(self, data: Any, tp: Type[WFMT], args: List[Any]) -> WFMT:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self, spec, configs)
#     127         wf = _make_top_level_workflow(spec, self.context, configs)
#     128         tasks_to_run = self.preprocess(wf)
# --> 129         self.run_tasks(tasks_to_run)
#     130
#     131     @abstractmethod
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_tasks(self, tasks)
#     153         if self._concurrency <= 1:
#     154             for t in tasks:
# --> 155                 self.run_single(t)
#     156             return
#     157         with cf.ThreadPoolExecutor(max_workers=self._concurrency) as e:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run_single(self, task)
#     170         task.update_by_cache()
#     171         task.run()
# --> 172         task.reraise()
#     173         return task
#     174
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in reraise(self)
#     712     def reraise(self):
#     713         if self.state == _State.FAILED:
# --> 714             reraise(
#     715                 type(self._exception),
#     716                 self._exception,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/adagio/instances.py in run(self)
#     681                 self._transit(_State.RUNNING)
#     682                 try:
# --> 683                     self.spec.func(TaskContext(self))
#     684                 except Exception as e:
#     685                     self._fail_remaining(e)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/workflow/_tasks.py in execute(self, ctx)
#     294             inputs = DataFrames(ctx.inputs.values())
#     295         self._processor.validate_on_runtime(inputs)
# --> 296         df = self._processor.process(inputs)
#     297         df = self.set_result(ctx, df)
#     298         ctx.outputs["_0"] = df
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/extensions/_builtins/processors.py in process(self, dfs)
#     152         engine_params = self.params.get("sql_engine_params", ParamDict())
#     153         sql_engine = make_sql_engine(engine, self.execution_engine, **engine_params)
# --> 154         return sql_engine.select(dfs, statement)
#     155
#     156
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/fugue/execution/native_execution_engine.py in select(self, dfs, statement)
#      72             for k, v in dfs.items()
#      73         }
# ---> 74         df = run_sql_on_pandas(
#      75             statement,
#      76             _dfs,
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/qpd_pandas/engine.py in run_sql_on_pandas(sql, dfs, ignore_case)
#      19     sql: str, dfs: Dict[str, Any], ignore_case: bool = False
#      20 ) -> pd.DataFrame:
# ---> 21     return run_sql(QPDPandasEngine(), sql, dfs, ignore_case=ignore_case)
#      22
#      23
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/qpd/run.py in run_sql(engine, sql, dfs, ignore_case)
#      21         )
#      22     )
# ---> 23     wf.assemble_output(v.visit(qsql.tree))
#      24     wf.run()
#      25     return ctx.result
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#    2370         def accept(self, visitor:ParseTreeVisitor):
#    2371             if hasattr( visitor, "visitSingleStatement" ):
# -> 2372                 return visitor.visitSingleStatement(self)
#    2373             else:
#    2374                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/qpd/_parser/visitors.py in visitSingleStatement(self, ctx)
#     471
#     472     def visitSingleStatement(self, ctx: qp.SingleStatementContext):
# --> 473         return self.visit(ctx.statement())
#     474
#     475     def visitCtes(self, ctx: qp.CtesContext) -> None:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#    3982         def accept(self, visitor:ParseTreeVisitor):
#    3983             if hasattr( visitor, "visitStatementDefault" ):
# -> 3984                 return visitor.visitStatementDefault(self)
#    3985             else:
#    3986                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlVisitor.py in visitStatementDefault(self, ctx)
#      47     # Visit a parse tree produced by sqlParser#statementDefault.
#      48     def visitStatementDefault(self, ctx:sqlParser.StatementDefaultContext):
# ---> 49         return self.visitChildren(ctx)
#      50
#      51
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visitChildren(self, node)
#      42
#      43             c = node.getChild(i)
# ---> 44             childResult = c.accept(self)
#      45             result = self.aggregateResult(result, childResult)
#      46
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#    7943         def accept(self, visitor:ParseTreeVisitor):
#    7944             if hasattr( visitor, "visitQuery" ):
# -> 7945                 return visitor.visitQuery(self)
#    7946             else:
#    7947                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/qpd/_parser/visitors.py in visitQuery(self, ctx)
#     467         if ctx.ctes() is not None:
#     468             self.visit(ctx.ctes())
# --> 469         df = self.visit(ctx.queryTerm())
#     470         return OrganizationVisitor(self).organize(df, ctx.queryOrganization())
#     471
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#   10259         def accept(self, visitor:ParseTreeVisitor):
#   10260             if hasattr( visitor, "visitQueryTermDefault" ):
# > 10261                 return visitor.visitQueryTermDefault(self)
#   10262             else:
#   10263                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlVisitor.py in visitQueryTermDefault(self, ctx)
#     562     # Visit a parse tree produced by sqlParser#queryTermDefault.
#     563     def visitQueryTermDefault(self, ctx:sqlParser.QueryTermDefaultContext):
# --> 564         return self.visitChildren(ctx)
#     565
#     566
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visitChildren(self, node)
#      42
#      43             c = node.getChild(i)
# ---> 44             childResult = c.accept(self)
#      45             result = self.aggregateResult(result, childResult)
#      46
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#   10476         def accept(self, visitor:ParseTreeVisitor):
#   10477             if hasattr( visitor, "visitQueryPrimaryDefault" ):
# > 10478                 return visitor.visitQueryPrimaryDefault(self)
#   10479             else:
#   10480                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlVisitor.py in visitQueryPrimaryDefault(self, ctx)
#     572     # Visit a parse tree produced by sqlParser#queryPrimaryDefault.
#     573     def visitQueryPrimaryDefault(self, ctx:sqlParser.QueryPrimaryDefaultContext):
# --> 574         return self.visitChildren(ctx)
#     575
#     576
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visitChildren(self, node)
#      42
#      43             c = node.getChild(i)
# ---> 44             childResult = c.accept(self)
#      45             result = self.aggregateResult(result, childResult)
#      46
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#   10925         def accept(self, visitor:ParseTreeVisitor):
#   10926             if hasattr( visitor, "visitRegularQuerySpecification" ):
# > 10927                 return visitor.visitRegularQuerySpecification(self)
#   10928             else:
#   10929                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/qpd/_parser/visitors.py in visitRegularQuerySpecification(self, ctx)
#     429         self, ctx: qp.RegularQuerySpecificationContext
#     430     ) -> DataFrame:
# --> 431         self.copy(PreScan).visit(ctx)
#     432         self.copy(FromVisitor).visit(ctx)
#     433         if ctx.whereClause() is not None:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#   10925         def accept(self, visitor:ParseTreeVisitor):
#   10926             if hasattr( visitor, "visitRegularQuerySpecification" ):
# > 10927                 return visitor.visitRegularQuerySpecification(self)
#   10928             else:
#   10929                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/qpd/_parser/visitors.py in visitRegularQuerySpecification(self, ctx)
#     150         )
#     151         if ctx.fromClause() is not None:
# --> 152             self.copy(PreFrom).visit(ctx.fromClause())
#     153         self.visit(ctx.selectClause())
#     154         if ctx.whereClause() is not None:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#   12082         def accept(self, visitor:ParseTreeVisitor):
#   12083             if hasattr( visitor, "visitFromClause" ):
# > 12084                 return visitor.visitFromClause(self)
#   12085             else:
#   12086                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/qpd/_parser/visitors.py in visitFromClause(self, ctx)
#     264         self.assert_support(len(rel) == 1, ctx)
#     265         self.assert_none(ctx.lateralView(), ctx.pivotClause())
# --> 266         self.visit(rel[0])
#     267         self.set("dfs", DataFrames({x.df_name: x.df for x in self.joins}))
#     268
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#   12829         def accept(self, visitor:ParseTreeVisitor):
#   12830             if hasattr( visitor, "visitRelation" ):
# > 12831                 return visitor.visitRelation(self)
#   12832             else:
#   12833                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/qpd/_parser/visitors.py in visitRelation(self, ctx)
#     272         self.add_join_relation(Join(name, df))
#     273         for j in joins:
# --> 274             self.visit(j)
#     275
#     276     def visitJoinRelation(self, ctx: qp.JoinRelationContext) -> None:
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#   12894         def accept(self, visitor:ParseTreeVisitor):
#   12895             if hasattr( visitor, "visitJoinRelation" ):
# > 12896                 return visitor.visitJoinRelation(self)
#   12897             else:
#   12898                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/qpd/_parser/visitors.py in visitJoinRelation(self, ctx)
#     277         join_type = normalize_join_type(self.to_str(ctx.joinType()))
#     278         natural = ctx.NATURAL() is not None
# --> 279         df, name = self.copy(RelationVisitor).visit(ctx.right)
#     280         self.add_join_relation(
#     281             Join(
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/_qpd_antlr/sqlParser.py in accept(self, visitor)
#   13845         def accept(self, visitor:ParseTreeVisitor):
#   13846             if hasattr( visitor, "visitTableName" ):
# > 13847                 return visitor.visitTableName(self)
#   13848             else:
#   13849                 return visitor.visitChildren(self)
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/qpd/_parser/visitors.py in visitTableName(self, ctx)
#     216         self.assert_none(ctx.sample())
#     217         df_name = self.to_str(ctx.multipartIdentifier(), "")
# --> 218         assert_or_throw(
#     219             df_name in self.dfs,
#     220             KeyError(f"{df_name} is not found in {list(self.dfs.keys())}"),
#
# ~/mambaforge/envs/budapestbi/lib/python3.9/site-packages/triad/utils/assertion.py in assert_or_throw(bool_exp, exception)
#      40             raise AssertionError()
#      41         if isinstance(_exception, Exception):
# ---> 42             raise _exception
#      43         if isinstance(_exception, str):
#      44             raise AssertionError(_exception)
#
# KeyError: "departments is not found in ['_0', '_1', '_2']"

# %%
# %%fsql dask
# SELECT order_id, aisle, product_name, department, reordered FROM order_products
# INNER JOIN products ON order_products.product_id = products.product_id
# INNER JOIN aisles ON products.aisle_id = aisles.aisle_id
# INNER JOIN departments ON departments.department_id = products.department_id
# SAVE OVERWRITE "/tmp/working/result.parquet"
# Out:
#    department_id  count
# 0              1   4007
# 1              2    548
# 2              3   1516
# 3              4   1684
# 4              5   1054
# <small>schema: department_id:long,count:long</small>
